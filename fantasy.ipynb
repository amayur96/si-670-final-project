# %% [markdown]
# ### How to run this notebook
#
# - **Install dependencies**:
#
# ```bash
# pip install espn_api nfl_data_py
# ```
#
# - **Find your league ID**:
#   - Open your league in the browser (e.g., [Team page](https://fantasy.espn.com/football/team?leagueId=567575)).
#   - The number after `leagueId=` is your `league_id`.
#
# - **Get `espn_s2` and `swid` cookie values**:
#   - Follow the guide: [espn-api discussion #150](https://github.com/cwendt94/espn-api/discussions/150).
#   - In your browser DevTools: Storage → Cookies → `https://fantasy.espn.com` and copy the values for `espn_s2` and `SWID`.
#
# - **References**:
#   - [espn-api GitHub](https://github.com/cwendt94/espn-api)
#   - [espn-api Wiki](https://github.com/cwendt94/espn-api/wiki)

# %%
from espn_api.football import League
import nfl_data_py as nfl
league = League(league_id=567575, year=2025, espn_s2='AECVN3FcAWfB56xxM5SnNVqsxq9soOxMmzDH1CfYYOkX3KIrzeGSsTMZ0CwJLPQoBYxLMp59ILoZ0CvUnTrBbU15b2PwD1v9fZRoO5iMb%2Fy%2FWPaOqPwlwSx2ShvBAt%2BSqJxtboHzcpSuSOgASzSNx4divXOEc4aVZjnOx7qRJ9YbE800NnLCNiLMBpaHjdZg%2BMN6vwCInJrKejPDXsmdjo%2FIkV0IfCLQHr6QHyJjLhqOwAPozqNPyGa1ZZT8DOxA%2BmpTsa5v9cgfJ4V%2BVZzxzr95KxBS0k%2BYJMt7OWSdA%2B2yUQ%3D%3D', swid='{280AA84B-DE12-4B3D-80F2-283BF634242B}')
team = league.teams[9]
player = team.roster[0]
print(player)
print(player.stats[13]["projected_points"])
print(player.stats[13]["points"])
# Out:
# Player(Bijan Robinson)
# 18.87
# 28.8
